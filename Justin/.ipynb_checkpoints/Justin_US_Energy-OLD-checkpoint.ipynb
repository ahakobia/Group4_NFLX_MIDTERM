# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from google.colab import files
#       3 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
import io

df = pd.read_csv(io.BytesIO(uploaded['organised_Gen.csv']))
df.head(10)
# Out:
#    Unnamed: 0  YEAR  MONTH STATE                         TYPE OF PRODUCER  \
# 0           0  2001      1    AK            Total Electric Power Industry
# 1           1  2001      1    AK            Total Electric Power Industry
# 2           2  2001      1    AK            Total Electric Power Industry
# 3           3  2001      1    AK            Total Electric Power Industry
# 4           4  2001      1    AK            Total Electric Power Industry
# 5           5  2001      1    AK            Total Electric Power Industry
# 6           6  2001      1    AK  Electric Generators, Electric Utilities
# 7           7  2001      1    AK  Electric Generators, Electric Utilities
# 8           8  2001      1    AK  Electric Generators, Electric Utilities
# 9           9  2001      1    AK  Electric Generators, Electric Utilities
#
#                 ENERGY SOURCE  GENERATION (Megawatthours)
# 0                        Coal                     46903.0
# 1                   Petroleum                     71085.0
# 2                 Natural Gas                    367521.0
# 3  Hydroelectric Conventional                    104549.0
# 4                        Wind                        87.0
# 5                       Total                    590145.0
# 6                        Coal                     18410.0
# 7                   Petroleum                     64883.0
# 8                 Natural Gas                    305277.0
# 9  Hydroelectric Conventional                    104549.0

# %%
df['TYPE OF PRODUCER'].unique()
# Out:
# array(['Total Electric Power Industry',
#        'Electric Generators, Electric Utilities',
#        'Combined Heat and Power, Electric Power',
#        'Combined Heat and Power, Commercial Power',
#        'Combined Heat and Power, Industrial Power',
#        'Electric Generators, Independent Power Producers'], dtype=object)

# %%
sources = list(df['ENERGY SOURCE'].unique())
print(sources)
# Out:
# ['Coal', 'Petroleum', 'Natural Gas', 'Hydroelectric Conventional', 'Wind', 'Total', 'Other Gases', 'Nuclear', 'Wood and Wood Derived Fuels', 'Other Biomass', 'Other', 'Solar Thermal and Photovoltaic', 'Pumped Storage', 'Geothermal']

# %%
for source in sources:
  df.loc[df['ENERGY SOURCE'] == source, [source]] = df['GENERATION (Megawatthours']

df = df.fillna(0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 for source in sources:
#       2   df.loc[df['ENERGY SOURCE'] == source, [source]] = df['GENERATION (Megawatthours']
#       4 df = df.fillna(0)
#
# NameError: name 'sources' is not defined

# %%
grouped_df = df.groupby(['TYPE OF PRODUCER'])[sources].sum()
grouped_df.head(6)
# Out:
#                                                      Coal  Petroleum  \
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power          3948.0     9281.0
# Combined Heat and Power, Electric Power            5377.0     7177.0
# Combined Heat and Power, Industrial Power          9112.0    10938.0
# Electric Generators, Electric Utilities           10262.0    13041.0
# Electric Generators, Independent Power Producers   6269.0     9381.0
# Total Electric Power Industry                     12674.0    13358.0
#
#                                                   Natural Gas  \
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power              9864.0
# Combined Heat and Power, Electric Power                8741.0
# Combined Heat and Power, Industrial Power             11896.0
# Electric Generators, Electric Utilities               12209.0
# Electric Generators, Independent Power Producers      10975.0
# Total Electric Power Industry                         12999.0
#
#                                                   Hydroelectric Conventional  \
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power                             2228.0
# Combined Heat and Power, Electric Power                                156.0
# Combined Heat and Power, Industrial Power                             3635.0
# Electric Generators, Electric Utilities                              11115.0
# Electric Generators, Independent Power Producers                      9120.0
# Total Electric Power Industry                                        12588.0
#
#                                                     Wind    Total  \
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power         1840.0  11160.0
# Combined Heat and Power, Electric Power              0.0  10253.0
# Combined Heat and Power, Industrial Power          934.0  12482.0
# Electric Generators, Electric Utilities           5473.0  13095.0
# Electric Generators, Independent Power Producers  8247.0  13002.0
# Total Electric Power Industry                     8927.0  13364.0
#
#                                                   Other Gases  Nuclear  \
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power               419.0      0.0
# Combined Heat and Power, Electric Power                2850.0      0.0
# Combined Heat and Power, Industrial Power              5240.0      0.0
# Electric Generators, Electric Utilities                1315.0   5226.0
# Electric Generators, Independent Power Producers       1358.0   3452.0
# Total Electric Power Industry                          7030.0   8076.0
#
#                                                   Wood and Wood Derived Fuels  \
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power                              2052.0
# Combined Heat and Power, Electric Power                                3653.0
# Combined Heat and Power, Industrial Power                              7763.0
# Electric Generators, Electric Utilities                                3296.0
# Electric Generators, Independent Power Producers                       4201.0
# Total Electric Power Industry                                          9559.0
#
#                                                   Other Biomass    Other  \
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power                6639.0   3575.0
# Combined Heat and Power, Electric Power                  5544.0   3370.0
# Combined Heat and Power, Industrial Power                7290.0   7309.0
# Electric Generators, Electric Utilities                  5328.0   4562.0
# Electric Generators, Independent Power Producers         9311.0   6051.0
# Total Electric Power Industry                           12036.0  11374.0
#
#                                                   Solar Thermal and Photovoltaic  \
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power                                 2660.0
# Combined Heat and Power, Electric Power                                    190.0
# Combined Heat and Power, Industrial Power                                 1205.0
# Electric Generators, Electric Utilities                                   3921.0
# Electric Generators, Independent Power Producers                          5465.0
# Total Electric Power Industry                                             5952.0
#
#                                                   Pumped Storage  Geothermal
# TYPE OF PRODUCER
# Combined Heat and Power, Commercial Power                  178.0        84.0
# Combined Heat and Power, Electric Power                      0.0        48.0
# Combined Heat and Power, Industrial Power                    0.0         0.0
# Electric Generators, Electric Utilities                   4105.0       844.0
# Electric Generators, Independent Power Producers          1028.0      1579.0
# Total Electric Power Industry                             4828.0      1687.0

# %%
grouped_df.columns
# Out:
# Index(['Coal', 'Petroleum', 'Natural Gas', 'Hydroelectric Conventional',
#        'Wind', 'Total', 'Other Gases', 'Nuclear',
#        'Wood and Wood Derived Fuels', 'Other Biomass', 'Other',
#        'Solar Thermal and Photovoltaic', 'Pumped Storage', 'Geothermal'],
#       dtype='object')

# %%
# grouped_df.plot.bar()
ax = grouped_df.loc[:, ['Petroleum', 'Coal', 'Natural Gas']].plot.bar(rot=90)
ax.set_ylabel("Number of Energy Sources")
ax.set_title("Types of Energy Sources by Producer")
# Out:
# Text(0.5, 1.0, 'Types of Energy Sources by Producer')
